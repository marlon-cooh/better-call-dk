# %%
import pandas as pd

# %%
pd.read_csv("prueba_2.csv").drop(columns={"Unnamed: 0"})
# Out:
#                                   Pregunta de prueba  \
# 0  ¿Cuál fue la sentencia del caso que habla de a...
# 1          ¿Cuáles son las sentencias de 3 demandas?
# 2     ¿De qué se trataron las 3 demandas anteriores?
# 3  ¿diga el detalle de la demanda relacionada con...
# 4  ¿existen casos que hablan sobre el PIAR, indiq...
#
#                                            Respuesta
# 0  El caso de acoso escolar es el T-249/24.\n\n¿Y...
# 1  Aquí tienes 3 sentencias:\n\n1) T-249/24 (26 d...
# 2  Claro, aquí tienes un resumen de las tres dema...
# 3  En el caso T-249/24, la situación fue la sigui...
# 4  Sí, hay al menos un caso que habla del PIAR: e...
